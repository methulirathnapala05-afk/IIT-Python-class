# %%
name= input("enter the name ")
marks=int(input("enter the marks"))
if marks >80 :
    print ("Name-",name,"Marks-",marks,"Grade-","A")
elif marks >=60:
    print("Name-",name,"Marks-",marks,"Grade-","B")
elif marks >=40:
    print("Name-", name, "Marks-",marks,"Grade-","C")
else:
    print("Name-",name,"Marks-",marks,"Grade-","F")
