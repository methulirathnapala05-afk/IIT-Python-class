# %%
a=5
b=2
a==b
# Out:
# False

# %%
a=5
b=2
a!=b
# Out:
# True

# %%
a=5
b=2
a<=b
# Out:
# False

# %%
a=5
b=2
a>=b
# Out:
# True

# %%
a=5
b=2
a>b
# Out:
# True

# %%
a=5
b=2
a<b
# Out:
# False

# %% [markdown]
# ### comparison operators

# %% [markdown]
#  ### Now logical operators

# %% [markdown]
# ### Not

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### And

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True and True
# Out:
# True

# %% [markdown]
# ### Or

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False
