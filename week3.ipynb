# %%
age=int(input("enter age"))
if (age>=18):
    print("Adult")
else:
    print("Minor")
# Out:
# enter age 20
# Adult

# %%
marks=int(input("enter marks"))
if marks>50:
    print("Pass")
else:
    print("Fail")
# Out:
# enter marks 80
# Pass

# %%
marks=int(input("enter marks"))
if (marks >= 75):
    print("Grade A")
elif (marks >=65):
    print("Grade B")
elif (marks >=50):
    print("Grade C")
else:
    print("Grade F")
# Out:
# enter marks 75
# Grade A
