# %%
print("Hello from JupyterLite!")
# Out:
# Hello from JupyterLite!

# %% [markdown]
# ### this is your chance

# %% [markdown]
# ### Arithmatic operators

# %%
5-2
# Out:
# 3

# %%
5+2
# Out:
# 7

# %%
5**2
# Out:
# 25

# %%
5*2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
a=5
b=3
a+=b
print(a)
# Out:
# 8

# %%
a=5
b=2
a-=b
print(a)
# Out:
# 3

# %%
a=5
b=3
a*=b
print(a)
# Out:
# 15

# %%
a=5
b=2
a/=b
print(a)
# Out:
# 2.5
