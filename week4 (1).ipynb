# %% [markdown]
# ## Without parameters

# %%
def calculate():
    print("Hello,welcome to python!")
    print("Wts up")
    print("It's rainy day")

# %%
calculate()
# Out:
# Hello,welcome to python!
# Wts up
# It's rainy day

# %%
def greet (name):
    print(f"Hello,{name}!")
greet("Methuli")
# Out:
# Hello,Methuli!

# %% [markdown]
# ## Default parameters

# %%
def greet(name="guest"):
    print(f"Hello,{name}!")
greet()
greet("Methuli")
# Out:
# Hello,guest!
# Hello,Methuli!

# %%
def calculate(a,b):
    return(a+b)

# %%
calculate(13,6)
# Out:
# 19

# %% [markdown]
#
# ## Control statement - Continue

# %%
for i in range (1,11,1):
    if i ==5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %% [markdown]
# ## pass statement

# %%
def calculate():
    pass

# %%
for i in range (1,11,1):
    pass

# %% [markdown]
# ## break statement

# %%
for i in range (1,11,1):
    if i ==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range (1,4):
    for j in range(1,4): 
        if j ==2:
            continue
    print(i,j)
# Out:
# 1 3
# 2 3
# 3 3

# %%
def name():
    print("Hello,World!")
name()
# Out:
# Hello,World!

# %%
def input(name):
    return(f"Hello,{name}!")

input("Methuli")
# Out:
# 'Hello,Methuli!'

# %%
def calculate (a,b):
    return(a+b)
  
calculate(50,20)
# Out:
# 70

# %%
def calculate (a):
    if a%2==0:
        return ("even")
    else:
        return("odd")
calculate(30)
# Out:
# 'even'

# %%
def square (x):
    print(x*x)
square(6)
# Out:
# 36

# %%
#### print("***Calculator***")
# menu
print("1.Addition")
print("2.Substraction")
print("3.Multiplication")
print ("4.Division")
print("5.Exit")
print("*******")

choice=int(input("enter the choice"))
number1=int(input("enter the first number ?"))
number2=int(input("enter the second number ?"))
# Out:
# 1.Addition
# 2.Substraction
# 3.Multiplication
# 4.Division
# 5.Exit
# *******
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 10
#       7 print("5.Exit")
#       8 print("*******")
# ---> 10 choice=int(input("enter the choice"))
#      11 number1=int(input("enter the first number ?"))
#      12 number2=int(input("enter the second number ?"))
#
# ValueError: invalid literal for int() with base 10: 'Hello,enter the choice!'

# %%
print("***Calculator***")
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
print("5.Exit")
print("*******")

choice = int(input("Enter the choice: "))
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))

if choice == 1:
    answer=num1+num2
elif:
    choice == 1:
    answer=num1-num2
elif:
    choice == 1:
    answer=num1+num2
# Out:
# ***Calculator***
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# *******
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 9
#       6 print("5.Exit")
#       7 print("*******")
# ----> 9 choice = int(input("Enter the choice: "))
#      10 number1 = int(input("Enter the first number: "))
#      11 number2 = int(input("Enter the second number: "))
#
# ValueError: invalid literal for int() with base 10: 'Hello,Enter the choice: !'

# %%
print("***Calculator***")
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
print("5.Exit")
print("*******")

choice = int(input("Enter the choice: "))

if choice == 5:
    print("Exiting...")
else:
    number1 = int(input("Enter the first number: "))
    number2 = int(input("Enter the second number: "))

    if choice == 1:
        print("Result:", number1 + number2)
    elif choice == 2:
        print("Result:", number1 - number2)
    elif choice == 3:
        print("Result:", number1 * number2)
    elif choice == 4:
        print("Result:", number1 / number2)
    else:
        print("Invalid choice")
# Out:
# ***Calculator***
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# *******
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 9
#       6 print("5.Exit")
#       7 print("*******")
# ----> 9 choice = int(input("Enter the choice: "))
#      11 if choice == 5:
#      12     print("Exiting...")
#
# ValueError: invalid literal for int() with base 10: 'Hello,Enter the choice: !'

# %%
print("***Calculator***")
# menu
print("1.Addition")
print("2.Substraction")
print("3.Multiplication")
print("4.Division")
print("5.Exit")
print("*******")

choice = input("enter the choice: ")
number1 = int(input("enter the first number ? "))
number2 = int(input("enter the second number ? "))
# Out:
# ***Calculator***
# 1.Addition
# 2.Substraction
# 3.Multiplication
# 4.Division
# 5.Exit
# *******
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 11
#       8 print("*******")
#      10 choice = input("enter the choice: ")
# ---> 11 number1 = int(input("enter the first number ? "))
#      12 number2 = int(input("enter the second number ? "))
#
# ValueError: invalid literal for int() with base 10: 'Hello,enter the first number ? !'
