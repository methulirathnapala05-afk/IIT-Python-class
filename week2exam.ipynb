# %%
a=int(input("enter the number"))
b=int(input("enter the number2"))
sum=a+b
diff=b-a
mul=a*b
dev=b/a
print("sum is",sum)
print("difference is ",diff)
print("multiplication is", mul)
print("devision is" , dev)
# Out:
# enter the number 20
# enter the number2 40
# sum is 60
# difference is  20
# multiplication is 800
# devision is 2.0

# %%
temperature=int(input("enter the temperature in celsius"))
temperature=temperature*9/5+32
print(temperature)
# Out:
# enter the temperature in celsius 100
# 212.0

# %%
Radius=int(input("enter the radius number"))
area=3.14*Radius
circumference=2*3.14*Radius
print(area)
print(circumference)
# Out:
# enter the radius number 7
# 21.98
# 43.96

# %%
number=int(input("enter the number"))
if number%2==0:
    print("even no")
else:
    print("odd no")
# Out:
# enter the number 20
# even no

# %%
sentence=input("enter the sentence")
count=len(sentence)
print(count)
# Out:
# enter the sentence The world is not too bad
# 24
