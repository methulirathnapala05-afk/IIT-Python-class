# %% [markdown]
# # IIT Python class

# %% [markdown]
# ## week 1 homeworks

# %% [markdown]
# ### very first command

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hi World')
# Out:
# Hi World

# %% [markdown]
# ### My name is Methuli,
# ### I work as a student,
# ### I learn Python Programming

# %%
print("My name is Methuli,")
print( "I work as a student,")
print( "I learn Python Programming")
# Out:
# My name is Methuli,
# I work as a student,
# I learn Python Programming
