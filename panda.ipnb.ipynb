# %%
import pandas as pd

s = pd.Series([85, 90, 88])
print(s)
# Out:
# 0    85
# 1    90
# 2    88
# dtype: int64

# %%
s.index=[20,30,40]
print(s)
# Out:
# 20    85
# 30    90
# 40    88
# dtype: int64

# %%
 marks = pd.Series([78, 85, 62, 90, 74])

# %%
numbers_s=pd.Series([10,20,30,40],index=["a","b","c","d"])

numbers_s.iloc[3]
numbers_s.loc["b"]
# Out:
# np.int64(20)

# %%
data = {'Name': ['Tom', 'nick', 'krish', 'jack'],
"Age": [20, 21, 19, 18],
"Marks":[95,85,64,72]}
methu=pd.DataFrame(data)
methu.loc[0:2]
# Out:
#     Name  Age  Marks
# 0    Tom   20     95
# 1   nick   21     85
# 2  krish   19     64

# %%
data = {'Name': ['Tom', 'nick', 'krish', 'jack'],
"Age": [20, 21, 19, 18],
"Marks":[95,85,64,72]}

methu=pd.DataFrame(data)
methu.loc[1,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 6
#       1 data = {'Name': ['Tom', 'nick', 'krish', 'jack'],
# ...

# %%
methu.index = ['A', 'B', 'C', 'D']
(methu)
# Out:
#     Name  Age  Marks
# A    Tom   20     95
# B   nick   21     85
# C  krish   19     64
# D   jack   18     72

# %%
data = {'Name': ['Tom', 'nick', 'krish', 'jack'],
"Age": [20, 21, 19, 18],
"Marks":[95,85,64,72]
}
Students=pd.DataFrame(data)
Students
# Out:
#     Name  Age  Marks
# 0    Tom   20     95
# 1   nick   21     85
# 2  krish   19     64
# 3   jack   18     72

# %%
import pandas as pd

data = {
    "BC": [65, 73, 82, 45, 93, 56],
    "DDI": [96, 88, 52, 77, 69, 48],
    "AM": [55, 43, 66, 80, 90, 78],
    "SMA": [45, 63, 56, 71, 92, 81],
    "AF": [68, 73, 46, 30, 85, 93],
    "BISC": [77, 81, 93, 74, 51, 42]
}

Marks = pd.DataFrame(data)
print(Marks)
# Out:
#    BC  DDI  AM  SMA  AF  BISC
# 0  65   96  55   45  68    77
# 1  73   88  43   63  73    81
# 2  82   52  66   56  46    93
# 3  45   77  80   71  30    74
# 4  93   69  90   92  85    51
# 5  56   48  78   81  93    42

# %%
Marks.columns
# Out:
# Index(['BC', 'DDI', 'AM', 'SMA', 'AF', 'BISC'], dtype='object')

# %%
Marks.iloc[0:7]
# Out:
#    BC  DDI  AM  SMA  AF  BISC
# 0  65   96  55   45  68    77
# 1  73   88  43   63  73    81
# 2  82   52  66   56  46    93
# 3  45   77  80   71  30    74
# 4  93   69  90   92  85    51
# 5  56   48  78   81  93    42

# %%
Marks.values
# Out:
# array([[65, 96, 55, 45, 68, 77],
#        [73, 88, 43, 63, 73, 81],
#        [82, 52, 66, 56, 46, 93],
#        [45, 77, 80, 71, 30, 74],
#        [93, 69, 90, 92, 85, 51],
#        [56, 48, 78, 81, 93, 42]])

# %%
Marks["DDI"]
# Out:
# 0    96
# 1    88
# 2    52
# 3    77
# 4    69
# 5    48
# Name: DDI, dtype: int64

# %%
Marks.iloc[2]
# Out:
# BC      82
# DDI     52
# AM      66
# SMA     56
# AF      46
# BISC    93
# Name: 2, dtype: int64

# %%
Marks.loc[:, "AM":"AF"]
# Out:
#    AM  SMA  AF
# 0  55   45  68
# 1  43   63  73
# 2  66   56  46
# 3  80   71  30
# 4  90   92  85
# 5  78   81  93

# %%
Marks[Marks["BC"] > 60]
# Out:
#    BC  DDI  AM  SMA  AF  BISC
# 0  65   96  55   45  68    77
# 1  73   88  43   63  73    81
# 2  82   52  66   56  46    93
# 4  93   69  90   92  85    51

# %%
Marks[(Marks["BC"] > 60) & (Marks["BISC"] < 55)]
