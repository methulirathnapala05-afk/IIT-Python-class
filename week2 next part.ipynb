# %%
Fname=input("enter the first number")
# Out:
# enter the first number Methuli

# %%
 Lname=input("enter the second name ")
# Out:
# enter the second name  Thewanji

# %%
subject=input("enter the marks")
# Out:
# enter the marks 20

# %%
subject1=int(input("enter the marks 1"))
# Out:
# enter the marks 1 20

# %%
subject2=int(input("enter the marks 2"))
# Out:
# enter the marks 2 40

# %%
subject3=int(input("enter the marks 3"))
# Out:
# enter the marks 3 78

# %%
subject4=int(input("enter the marks 4"))
# Out:
# enter the marks 4 57

# %%
total = subject1+subject2+subject3+subject4
print(total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 total = subject1+subject2+subject3+subject4
#       2 print(total)
#
# TypeError: can only concatenate str (not "int") to str

# %%
subject1=int(input("enter the marks 1"))
subject2=int(input("enter the marks 2"))
subject3=int(input("enter the marks 3"))
subject4=int(input("enter the marks 4"))
total = subject1+subject2+subject3+subject4
average=total/4
print(Fname)
print(Lname)
print(subject1)
print(subject2)
print(subject3)
print(subject4)
print("")
print(total)
print(average)
# Out:
# enter the marks 1 20
# enter the marks 2 55
# enter the marks 3 78
# enter the marks 4 91
# Methuli
# Thewanji
# 20
# 55
# 78
# 91
#
# 244
# 61.0

# %%
print(Fname,",",Lname,subject1)
# Out:
# Methuli , Thewanji 20
